# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
from utils import plot_reward_comparison
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
beam_10_1_new_fn = 'data/beam_data/trajectory/diffusion_analysis_new_7JJK_beam_10_1.csv'
beam_10_1_old_fn = 'data/beam_data/trajectory/diffusion_analysis_old_7JJK_beam_10_1.csv'
bon_10_new_fn = 'data/bon_data/trajectory/diffusion_analysis_new_7JJK_bon_10.csv'
bon_10_old_fn = 'data/bon_data/trajectory/diffusion_analysis_old_7JJK_bon_10.csv'
base_new_fn = 'data/baseline_data/trajectory/diffusion_analysis_new_7JJK.csv'
base_old_fn = 'data/baseline_data/trajectory/diffusion_analysis_old_7JJK.csv'

# %%
beam_10_1_new_df = pd.read_csv(beam_10_1_new_fn)
beam_10_1_old_df = pd.read_csv(beam_10_1_old_fn)
bon_10_new_df = pd.read_csv(bon_10_new_fn)
bon_10_old_df = pd.read_csv(bon_10_old_fn)
base_new_df = pd.read_csv(base_new_fn)
base_old_df = pd.read_csv(base_old_fn)

# %%
beam_10_1_new_r = beam_10_1_new_df['Reward Average']
beam_10_1_old_r = beam_10_1_old_df['Reward Average']
bon_10_new_r = bon_10_new_df['Reward Average']
bon_10_old_r = bon_10_old_df['Reward Average']
base_new_r = base_new_df['Reward Average']
base_old_r = base_old_df['Reward Average']

# %%
iterations = np.arange(len(base_old_r)) + 1
all_reward = [base_new_r, base_old_r,  bon_10_new_r, bon_10_old_r, beam_10_1_new_r, beam_10_1_old_r]
colors = ['#0C8CE1', '#0C8CE1', '#F0724F', '#F0724F', '#1C9D36', '#1C9D36']
#colors = ['#0C8CE1', '#0C8CE1', '#8C33EB', '#8C33EB', '#6CA783', '#6CA783']
linestyles = ['-', '--', '-', '--', '-', '--']
labels = ['DRAKES', 'Pretrain', 'DRAKES-BON', 'Pretrain-BON', 'DRAKES-BEAM', 'Pretrain-BEAM']
title = ''#'BEAM & Best-of-N Comparison: 7JJK'
reward_label = 'Average Predicted ΔΔG'

plot_reward_comparison(iterations, all_reward, colors, linestyles, labels, title, reward_label)

# %%
beam_10_5_new_fn = 'data/beam_data/trajectory/diffusion_analysis_new_7JJK_beam_10_5.csv'
beam_10_10_new_fn = 'data/beam_data/trajectory/diffusion_analysis_new_7JJK_beam_10_10.csv'
beam_10_5_old_fn = 'data/beam_data/trajectory/diffusion_analysis_old_7JJK_beam_10_5.csv'
beam_10_10_old_fn = 'data/beam_data/trajectory/diffusion_analysis_old_7JJK_beam_10_10.csv'

# %%
beam_10_5_new_df = pd.read_csv(beam_10_5_new_fn)
beam_10_10_new_df = pd.read_csv(beam_10_10_new_fn)
beam_10_5_old_df = pd.read_csv(beam_10_5_old_fn)
beam_10_10_old_df = pd.read_csv(beam_10_10_old_fn)

# %%
beam_10_5_new_r = beam_10_5_new_df['Reward Average']
beam_10_10_new_r = beam_10_10_new_df['Reward Average']
beam_10_5_old_r = beam_10_5_old_df['Reward Average']
beam_10_10_old_r = beam_10_10_old_df['Reward Average']

# %%
iterations = np.arange(len(beam_10_1_new_r)) + 1
all_reward = [beam_10_1_new_r, beam_10_1_old_r, beam_10_5_new_r, beam_10_5_old_r, beam_10_10_new_r, beam_10_10_old_r]
colors = ['#0C8CE1', '#0C8CE1', '#F0724F', '#F0724F', '#1C9D36', '#1C9D36']
linestyles = ['-', '--', '-', '--', '-', '--']
labels = ['DRAKES (N=10, A=1)', 'Pretrain (N=10, A=1)', 'DRAKES (N=10, A=5)', 'Pretrain (N=10, A=5)', 'DRAKES (N=10, A=10)', 'Pretrain (N=10, A=10)']
title = 'BEAM Alternating Steps Comparison: 7JJK'
reward_label = 'Average Predicted ΔΔG'

plot_reward_comparison(iterations, all_reward, colors, linestyles, labels, title, reward_label)

# %%
soft_beam_10_1_new_fn = 'data/beam_data/trajectory/diffusion_analysis_new_7JJK_soft_beam_10_1.csv'
soft_beam_10_5_new_fn = 'data/beam_data/trajectory/diffusion_analysis_new_7JJK_soft_beam_10_5.csv'

# %%
soft_beam_10_1_new_df = pd.read_csv(soft_beam_10_1_new_fn)
soft_beam_10_5_new_df = pd.read_csv(soft_beam_10_5_new_fn)

# %%
soft_beam_10_1_new_r = soft_beam_10_1_new_df['Reward Average']
soft_beam_10_5_new_r = soft_beam_10_5_new_df['Reward Average']

# %%
iterations = np.arange(len(beam_10_1_new_r)) + 1
all_reward = [beam_10_1_new_r, soft_beam_10_1_new_r, beam_10_5_new_r, soft_beam_10_5_new_r]
colors = ['#0C8CE1', '#0C8CE1', '#F0724F', '#F0724F']
linestyles = ['-', '--', '-', '--']
labels = ['BEAM (N=10, A=1)', 'Soft-BEAM (N=10, A=1)', 'BEAM (N=10, A=5)', 'Soft-BEAM (N=10, A=5)']
title = 'DRAKES-Soft-BEAM Comparison: 7JJK'
reward_label = 'Average Predicted ΔΔG'

plot_reward_comparison(iterations, all_reward, colors, linestyles, labels, title, reward_label)

# %%
beam_10_1_new_protgpt_fn = 'data/beam_data/trajectory/diffusion_analysis_new_7JJK_protgpt_beam_10_1_all.csv'
beam_10_1_old_protgpt_fn = 'data/beam_data/trajectory/diffusion_analysis_old_7JJK_protgpt_beam_10_1_all.csv'
bon_10_new_protgpt_fn = 'data/bon_data/trajectory/diffusion_analysis_new_7JJK_protgpt_bon_10_all.csv'
bon_10_old_protgpt_fn = 'data/bon_data/trajectory/diffusion_analysis_old_7JJK_protgpt_bon_10_all.csv'
base_new_protgpt_fn = 'data/baseline_data/trajectory/diffusion_analysis_new_7JJK_protgpt_baseline_all.csv'
base_old_protgpt_fn = 'data/baseline_data/trajectory/diffusion_analysis_old_7JJK_protgpt_baseline_all.csv'

# %%
beam_10_1_new_protgpt_df = pd.read_csv(beam_10_1_new_protgpt_fn)
beam_10_1_old_protgpt_df = pd.read_csv(beam_10_1_old_protgpt_fn)
bon_10_new_protgpt_df = pd.read_csv(bon_10_new_protgpt_fn)
bon_10_old_protgpt_df = pd.read_csv(bon_10_old_protgpt_fn)
base_new_protgpt_df = pd.read_csv(base_new_protgpt_fn)
base_old_protgpt_df = pd.read_csv(base_old_protgpt_fn)

# %%
beam_10_1_new_protgpt_r = beam_10_1_new_protgpt_df['Reward Average']
beam_10_1_old_protgpt_r = beam_10_1_old_protgpt_df['Reward Average']
bon_10_new_protgpt_r = bon_10_new_protgpt_df['Reward Average']
bon_10_old_protgpt_r = bon_10_old_protgpt_df['Reward Average']
base_new_protgpt_r = base_new_protgpt_df['Reward Average']
base_old_protgpt_r = base_old_protgpt_df['Reward Average']

# %%
iterations = np.arange(len(base_old_protgpt_r)) + 1
all_reward = [base_new_protgpt_r, base_old_protgpt_r,  bon_10_new_protgpt_r, bon_10_old_protgpt_r, beam_10_1_new_protgpt_r, beam_10_1_old_protgpt_r]
colors = ['#0C8CE1', '#0C8CE1', '#F0724F', '#F0724F', '#1C9D36', '#1C9D36']
linestyles = ['-', '--', '-', '--', '-', '--']
labels = ['DRAKES', 'Pretrain', 'DRAKES-BON', 'Pretrain-BON', 'DRAKES-BEAM', 'Pretrain-BEAM']
title = 'ProtGPT Alignment: Average Over 12 Structures'
reward_label = 'ProtGPT Log Likelihood'

plot_reward_comparison(iterations, all_reward, colors, linestyles, labels, title, reward_label)

# %%
pg_old_fn = 'data_full/comp_250/diffusion_analysis_old_7JJK_protgpt.csv'
bon_pg_old_fn = 'data_full/comp_250/diffusion_analysis_old_7JJK_bon_protgpt_250_1.csv'
beam_pg_old_fn = 'data_full/comp_250/diffusion_analysis_old_7JJK_beam_protgpt_250_1.csv'
spectral_pg_old_fn = 'data_full/comp_250/diffusion_analysis_old_7JJK_spectral_protgpt_250_1.csv'
pg_new_fn = 'data_full/comp_250/diffusion_analysis_new_7JJK_protgpt.csv'
bon_pg_new_fn = 'data_full/comp_250/diffusion_analysis_new_7JJK_bon_protgpt_250_1.csv'
beam_pg_new_fn = 'data_full/comp_250/diffusion_analysis_new_7JJK_beam_protgpt_250_1.csv'
spectral_pg_new_fn = 'data_full/comp_250/diffusion_analysis_new_7JJK_spectral_protgpt_250_1.csv'

# %%
pg_old = pd.read_csv(pg_old_fn)
bon_pg_old = pd.read_csv(bon_pg_old_fn)
beam_pg_old = pd.read_csv(beam_pg_old_fn)
spectral_pg_old = pd.read_csv(spectral_pg_old_fn)
pg_new = pd.read_csv(pg_new_fn)
bon_pg_new = pd.read_csv(bon_pg_new_fn)
beam_pg_new = pd.read_csv(beam_pg_new_fn)
spectral_pg_new = pd.read_csv(spectral_pg_new_fn)

# %%
pg_old_r = pg_old['Reward Average']
bon_pg_old_r = bon_pg_old['Reward Average']
beam_pg_old_r = beam_pg_old['Reward Average']
spectral_pg_old_r = spectral_pg_old['Reward Average']
pg_new_r = pg_new['Reward Average']
bon_pg_new_r = bon_pg_new['Reward Average']
beam_pg_new_r = beam_pg_new['Reward Average']
spectral_pg_new_r = spectral_pg_new['Reward Average']

# %%
iterations = np.arange(len(base_old_protgpt_r)) + 1
all_reward = [pg_new_r, bon_pg_new_r, beam_pg_new_r, spectral_pg_new_r, pg_old_r, bon_pg_old_r, beam_pg_old_r, spectral_pg_old_r]
colors = ['#3792F4', '#2AA8F5', '#51D4F5', '#A2F5EB', "#F5DD51", "#F5C951", "#F58D37", "#F55B0C"]
linestyles = ['-'] * 4 + ['--'] * 4
labels = ['DRAKES', 'DRAKES-BON', 'DRAKES-BEAM', 'DRAKES-Spectral', 'Pretrain', 'Pretrain-BON', 'Pretrain-BEAM', 'Pretrain-Spectral']
title = ''
reward_label = 'ProtGPT Log Likelihood'

plot_reward_comparison(iterations, all_reward, colors, linestyles, labels, title, reward_label)
