# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import matplotlib.pyplot as plt
from utils import get_eval_stats, analyze_protein_gen_helper, analyze_protein_gen_helper_violin, plot_line_prot_comp
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pretrained_file = 'data/baseline_data/distribution/original_old_10_0.5_0_results_merge.csv' 
drakes_file = 'data/baseline_data/distribution/original_new_10_0.5_0_results_merge.csv' 
df_pre = pd.read_csv(pretrained_file)
df_drakes = pd.read_csv(drakes_file)

# print("---Pretrained---")
# pre_stats = display_eval(df_pre)
# print("\n-----DRAKES-----")
# drakes_stats = display_eval(df_drakes)

# %%
data = [df_pre, df_drakes]
labels = ['Pretrained', 'DRAKES']
colors = ['#E6D983', '#0C8CE1']
analyze_protein_gen_helper('7JJK', data, labels, colors, 'rewards_eval', y_label='Predicted ΔΔG', v_line_thresh=0, v_line_label='Wild-type')

# %%
analyze_protein_gen_helper('7JJK', data, labels, colors, 'gen_true_bb_rmsd', y_label='scRMSD')

# %%
analyze_protein_gen_helper('7JJK', data, labels, colors, 'loglikelihood', y_label='ProtGPT Log Likelihood')

# %%
print("\n---BON 10---")
bon_10_dist_old_fn = 'data/bon_data/distribution/original_old_10_0.5_0_results_merge_old_7JJK_bon_10.csv'
df_bon_10_old = pd.read_csv(bon_10_dist_old_fn)
# bon_10_stats_7jjk_old = display_eval(df_bon_10_old, '7JJK')

print("\n---BEAM 10---")
beam_10_dist_old_fn = 'data/beam_data/distribution/original_old_10_0.5_0_results_merge_old_7JJK_beam_10_1.csv'
df_beam_10_old = pd.read_csv(beam_10_dist_old_fn)
# beam_10_stats_7jjk_old = display_eval(df_beam_10_old, '7JJK')
# Out:
# ---BON 10---
#
# ---BEAM 10---

# %%
data = [df_pre, df_bon_10_old, df_beam_10_old]
labels = ['Pretrained', 'Pretrained-BON (10)', 'Pretrained-BEAM (10)']
colors = ['#E6D983', '#0C8CE1', '#8C33EB']
analyze_protein_gen_helper('7JJK', data, labels, colors, 'rewards_eval', y_label='Predicted ΔΔG', v_line_thresh=0, v_line_label='Wild-type')

# %%
analyze_protein_gen_helper('7JJK', data, labels, colors, 'gen_true_bb_rmsd', y_label='scRMSD')

# %%
analyze_protein_gen_helper('7JJK', data, labels, colors, 'loglikelihood', y_label='ProtGPT Log Likelihood')

# %%
print("\n---DRAKES-BON 10---")
bon_10_dist_new_fn = 'data/bon_data/distribution/original_new_10_0.5_0_results_merge_bon_10.csv'
df_bon_10_new = pd.read_csv(bon_10_dist_new_fn)
# bon_10_stats_7jjk_new = display_eval(df_bon_10_new, '7JJK')

print("\n---DRAKES-BEAM 10---")
beam_10_dist_new_fn = 'data/beam_data/distribution/original_new_10_0.5_0_results_merge_beam_10_1.csv'
df_beam_10_new = pd.read_csv(beam_10_dist_new_fn)
# beam_10_stats_7jjk_new = display_eval(df_beam_10_new, '7JJK')
# Out:
# ---DRAKES-BON 10---
#
# ---DRAKES-BEAM 10---

# %%
data = [df_drakes, df_bon_10_new, df_beam_10_new]
labels = ['DRAKES', 'DRAKES-BON (10)', 'DRAKES-BEAM (10)']
colors = ['#6CA783', '#0C8CE1', '#8C33EB']
analyze_protein_gen_helper('7JJK', data, labels, colors, 'rewards_eval', y_label='Predicted ΔΔG', v_line_thresh=0, v_line_label='Wild-type')

# %%
analyze_protein_gen_helper('7JJK', data, labels, colors, 'gen_true_bb_rmsd', y_label='scRMSD')

# %%
analyze_protein_gen_helper('7JJK', data, labels, colors, 'loglikelihood', y_label='ProtGPT Log Likelihood')

# %%
print("\n---DRAKES-SCRMSD-BON 5---")
bon_5_dist_new_scrmsd_fn = 'data/bon_data/distribution/original_new_10_0.5_0_results_merge_new_7JJK_scrmsd_bon_5.csv'
df_bon_5_new_scrmsd = pd.read_csv(bon_5_dist_new_scrmsd_fn)
# bon_5_stats_7jjk_new_scrmsd = display_eval(df_bon_5_new_scrmsd, '7JJK')

print("\n---DRAKES-SCRMSD-BEAM 5,5---")
beam_5_5_dist_new_scrmsd_fn = 'data/beam_data/distribution/original_new_10_0.5_0_results_merge_new_7JJK_scrmsd_beam_5_5.csv'
df_beam_5_5_new_scrmsd = pd.read_csv(beam_5_5_dist_new_scrmsd_fn)
#beam_5_5_stats_7jjk_new_scrmsd = display_eval(df_beam_5_5_new_scrmsd, '7JJK')
# Out:
# ---DRAKES-SCRMSD-BON 5---
#
# ---DRAKES-SCRMSD-BEAM 5,5---

# %%
data = [df_drakes, df_bon_5_new_scrmsd, df_beam_5_5_new_scrmsd]
labels = ['DRAKES', 'DRAKES-SCRMSD-BON (5)', 'DRAKES-SCRMSD-BEAM (5, 5)']
colors = ['#6CA783', '#0C8CE1', '#8C33EB']
analyze_protein_gen_helper('7JJK', data, labels, colors, 'rewards_eval', y_label='Predicted ΔΔG', v_line_thresh=0, v_line_label='Wild-type')

# %%
analyze_protein_gen_helper('7JJK', data, labels, colors, 'gen_true_bb_rmsd', y_label='scRMSD')

# %%
analyze_protein_gen_helper('7JJK', data, labels, colors, 'loglikelihood', y_label='ProtGPT Log Likelihood')

# %%
print("\n---PRETRAINED-SCRMSD-BON 5---")
bon_5_dist_old_scrmsd_fn = 'data/bon_data/distribution/original_old_10_0.5_0_results_merge_old_7JJK_scrmsd_bon_5.csv'
df_bon_5_old_scrmsd = pd.read_csv(bon_5_dist_old_scrmsd_fn)
# bon_5_stats_7jjk_old_scrmsd = display_eval(df_bon_5_old_scrmsd, '7JJK')

print("\n---PRETRAINED-SCRMSD-BEAM 5,5---")
beam_5_5_dist_old_scrmsd_fn = 'data/beam_data/distribution/original_old_10_0.5_0_results_merge_old_7JJK_scrmsd_beam_5_5.csv'
df_beam_5_5_old_scrmsd = pd.read_csv(beam_5_5_dist_old_scrmsd_fn)
# beam_5_5_stats_7jjk_old_scrmsd = display_eval(df_beam_5_5_old_scrmsd, '7JJK')
# Out:
# ---PRETRAINED-SCRMSD-BON 5---
#
# ---PRETRAINED-SCRMSD-BEAM 5,5---

# %%
data = [df_pre, df_bon_5_old_scrmsd, df_beam_5_5_old_scrmsd]
labels = ['Pretrained', 'Pretrained-SCRMSD-BON (5)', 'Pretrained-SCRMSD-BEAM (5, 5)']
colors = ['#6CA783', '#0C8CE1', '#8C33EB']
analyze_protein_gen_helper('7JJK', data, labels, colors, 'rewards_eval', y_label='Predicted ΔΔG', v_line_thresh=0, v_line_label='Wild-type')

# %%
analyze_protein_gen_helper('7JJK', data, labels, colors, 'gen_true_bb_rmsd', y_label='scRMSD')

# %%
analyze_protein_gen_helper('7JJK', data, labels, colors, 'loglikelihood', y_label='ProtGPT Log Likelihood')

# %%
print("\n---PRETRAINED---")
dist_old_fn = 'data_full/baseline/pretrained/distribution/original_old_10_0.5_0_results_merge_old_baseline.csv'
df_dist_old = pd.read_csv(dist_old_fn)
# stats_old = display_eval(df_dist_old, '7JJK')

print("\n---PRETRAINED-PROTGPT-BON 10---")
bon_10_dist_old_protgpt_fn = 'data_full/bon/pretrained/distribution/original_old_10_0.5_0_results_merge_old_protgpt_bon_10.csv'
df_bon_10_dist_old_protgpt = pd.read_csv(bon_10_dist_old_protgpt_fn)
# bon_10_stats_old_scrmsd = display_eval(df_bon_10_dist_old_protgpt, '7JJK')

print("\n---PRETRAINED-ProtGPT-BEAM 10,1---")
beam_10_1_dist_old_protgpt_fn = 'data_full/beam/pretrained/distribution/original_old_10_0.5_0_results_merge_old_protgpt_beam_10_1.csv'
df_beam_10_1_old_protgpt = pd.read_csv(beam_10_1_dist_old_protgpt_fn)
# beam_10_stats_old_scrmsd = display_eval(df_beam_5_5_old_scrmsd, '7JJK')
# Out:
# ---PRETRAINED---
#
# ---PRETRAINED-PROTGPT-BON 10---
#
# ---PRETRAINED-ProtGPT-BEAM 10,1---

# %%
data = [df_dist_old, df_bon_10_dist_old_protgpt, df_beam_10_1_old_protgpt]
labels = ['Pretrained', 'Pretrained-ProtGPT-BON (10)', 'Pretrained-ProtGPT-BEAM (10, 1)']
colors = ['#6CA783', '#0C8CE1', '#8C33EB']
analyze_protein_gen_helper('7JJK', data, labels, colors, 'ddg_eval', y_label='Predicted ΔΔG', v_line_thresh=0, v_line_label='Wild-type')

# %%
#analyze_protein_gen_helper('7JJK', data, labels, colors, 'scrmsd', y_label='scRMSD')

# %%
analyze_protein_gen_helper('7JJK', data, labels, colors, 'loglikelihood', y_label='ProtGPT Log Likelihood')

# %%
print("\n---DRAKES---")
dist_new_fn = 'data_full/baseline/drakes/distribution/original_new_10_0.5_0_results_merge_new_baseline.csv'
df_dist_new = pd.read_csv(dist_new_fn)

print("\n---DRAKES-PROTGPT-BON 10---")
bon_10_dist_new_protgpt_fn = 'data_full/bon/drakes/distribution/original_new_10_0.5_0_results_merge_new_protgpt_bon_10.csv'
df_bon_10_dist_new_protgpt = pd.read_csv(bon_10_dist_new_protgpt_fn)

print("\n---DRAKES-PROTGPT-BON 250---")
bon_250_dist_new_protgpt_fn = 'data_full/bon/drakes/distribution/original_new_10_0.5_0_results_merge_new_7JJK_protgpt_bon_250.csv'
df_bon_250_dist_new_protgpt = pd.read_csv(bon_250_dist_new_protgpt_fn)

print("\n---DRAKES-ProtGPT-BEAM 10,1---")
beam_10_1_dist_new_protgpt_fn = 'data_full/beam/drakes/distribution/original_new_10_0.5_0_results_merge_new_protgpt_beam_10_1.csv'
df_beam_10_1_new_protgpt = pd.read_csv(beam_10_1_dist_new_protgpt_fn)

print("\n---DRAKES-ProtGPT-BEAM 250,1---")
beam_250_1_dist_new_protgpt_fn = 'data_full/beam/drakes/distribution/original_new_10_0.5_0_results_merge_new_7JJK_protgpt_beam_250_1.csv'
df_beam_250_1_new_protgpt = pd.read_csv(beam_250_1_dist_new_protgpt_fn)

print("\n--DRAKES-ProtGPT-Spectral 250---")
spectral_250_dist_new_protgpt_fn = 'data_full/beam/drakes/distribution/original_new_10_0.5_0_results_merge_new_7JJK_protgpt_spectral_50250_1.csv'#original_new_10_0.5_0_results_merge_new_7JJK_protgpt_spectral_250_1.csv'
df_spectral_250_new_protgpt = pd.read_csv(spectral_250_dist_new_protgpt_fn)
# Out:
# ---DRAKES---
#
# ---DRAKES-PROTGPT-BON 10---
#
# ---DRAKES-PROTGPT-BON 250---
#
# ---DRAKES-ProtGPT-BEAM 10,1---
#
# ---DRAKES-ProtGPT-BEAM 250,1---
#
# --DRAKES-ProtGPT-Spectral 250---

# %%
data = [df_dist_new, df_bon_250_dist_new_protgpt, df_beam_250_1_new_protgpt, df_spectral_250_new_protgpt]
labels = ['DRAKES', 'DRAKES-ProtGPT-BON (250)', 'DRAKES-ProtGPT-BEAM (250, 1)', 'DRAKES-ProtGPT-Spectral (250)']
colors =  ['#6CA783', '#0C8CE1', '#8C33EB', "#DE9D12"]
analyze_protein_gen_helper('7JJK', data, labels, colors, 'ddg_eval', y_label='Predicted ΔΔG', v_line_thresh=0, v_line_label='Wild-type')

# %%
analyze_protein_gen_helper('7JJK', data, labels, colors, 'scrmsd', y_label='scRMSD')

# %%
analyze_protein_gen_helper('7JJK', data, labels, colors, 'loglikelihood', y_label='ProtGPT Log Likelihood')

# %%
data = [df_dist_old, df_dist_new, df_bon_250_dist_new_protgpt, df_beam_250_1_new_protgpt, df_spectral_250_new_protgpt]
labels = ['Pretrained', 'DRAKES', 'DRAKES-ProtGPT-BON (250)', 'DRAKES-ProtGPT-BEAM (250, 1)', 'DRAKES_ProtGPT-Spectral (250)']
colors = ['#6CA783', '#0C8CE1', '#8C33EB', "#C500C5", "#DE9D12"]
analyze_protein_gen_helper('7JJK', data, labels, colors, 'loglikelihood', y_label='ProtGPT Log Likelihood')

# %%
analyze_protein_gen_helper('7JJK', data, labels, colors, 'ddg_eval', y_label='Predicted ΔΔG', v_line_thresh=0, v_line_label='Wild-type')

# %%
import pandas as pd
import matplotlib.pyplot as plt
from utils import get_eval_stats, analyze_protein_gen_helper, analyze_protein_gen_helper_violin, plot_line_prot_comp

data = [df_dist_new, df_bon_10_dist_new_protgpt, df_beam_10_1_new_protgpt, df_dist_old, df_bon_10_dist_old_protgpt, df_beam_10_1_old_protgpt]
labels = ['DRAKES', 'DRAKES-BON', 'DRAKES-BEAM', 'Pretrained', 'Pretrained-BON', 'Pretrained-BEAM']
colors = ['#3792F4', '#51D4F5', '#A2F5EB', "#F5DD51", "#F5C951", "#F58D37"]
analyze_protein_gen_helper_violin('7JJK', data, labels, colors, 'loglikelihood', y_label='ProtGPT Log Likelihood')

# %%
import pandas as pd
import matplotlib.pyplot as plt
from utils import get_eval_stats, analyze_protein_gen_helper, analyze_protein_gen_helper_violin, plot_line_prot_comp

data = [df_drakes, df_bon_10_new, df_beam_10_new, df_pre, df_bon_10_old, df_beam_10_old]
labels = ['DRAKES', 'DRAKES-DDG-BON (10)', 'DRAKES-DDG-BEAM (10, 1)', 'Pretrained', 'Pretrained-DDG-BON (10)', 'Pretrained-DDG-BEAM (10, 1)']
colors = ['#3792F4', '#51D4F5', '#A2F5EB', "#F5DD51", "#F5C951", "#F58D37"]
analyze_protein_gen_helper_violin('7JJK', data, labels, colors, 'rewards_eval', y_label='Predicted ΔΔG')

# %%
analyze_protein_gen_helper('7JJK', data, labels, colors, 'scrmsd', y_label='scRMSD')

# %%
analyze_protein_gen_helper('7JJK', data, labels, colors, 'ddg_eval', y_label='Predicted ΔΔG', v_line_thresh=0, v_line_label='Wild-type')

# %%
plot_line_prot_comp('pred_ddg_med', 
                [[pre_stats, bon_10_stats_7jjk_old, beam_10_stats_7jjk_old], \
                    [drakes_stats, bon_10_stats_7jjk_new, beam_10_stats_7jjk_new], \
                    [pre_stats, bon_5_stats_7jjk_old_scrmsd, beam_5_5_stats_7jjk_old_scrmsd], \
                    [drakes_stats, bon_5_stats_7jjk_new_scrmsd, beam_5_5_stats_7jjk_new_scrmsd]], \
                ['Pretrained', 'DRAKES', 'Pretrained-SCRMSD', 'DRAKES-SCRMSD'],\
                ['Baseline', 'Best-of-N', 'BEAM'],
                y_label='Median Predicted ΔΔG',
                h_line_threshold=0,
                h_line_label='Wild-type',
                title='7JJK')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[113], line 2
#       1 plot_line_prot_comp('pred_ddg_med',
# ----> 2                 [[pre_stats, bon_10_stats_7jjk_old, beam_10_stats_7jjk_old], \
#       3                     [drakes_stats, bon_10_stats_7jjk_new, beam_10_stats_7jjk_new], \
#       4                     [pre_stats, bon_5_stats_7jjk_old_scrmsd, beam_5_5_stats_7jjk_old_scrmsd], \
#       5                     [drakes_stats, bon_5_stats_7jjk_new_scrmsd, beam_5_5_stats_7jjk_new_scrmsd]], \
#       6                 ['Pretrained', 'DRAKES', 'Pretrained-SCRMSD', 'DRAKES-SCRMSD'],\
#       7                 ['Baseline', 'Best-of-N', 'BEAM'],
#       8                 y_label='Median Predicted ΔΔG',
#       9                 h_line_threshold=0,
#      10                 h_line_label='Wild-type',
#      11                 title='7JJK')
#
# ...

# %%
plot_line_prot_comp('scRMSD_med', 
                [[pre_stats, bon_10_stats_7jjk_old, beam_10_stats_7jjk_old], \
                    [drakes_stats, bon_10_stats_7jjk_new, beam_10_stats_7jjk_new], \
                    [pre_stats, bon_5_stats_7jjk_old_scrmsd, beam_5_5_stats_7jjk_old_scrmsd], \
                    [drakes_stats, bon_5_stats_7jjk_new_scrmsd, beam_5_5_stats_7jjk_new_scrmsd]], \
                ['Pretrained', 'DRAKES', 'Pretrained-SCRMSD', 'DRAKES-SCRMSD'],\
                ['Baseline', 'Best-of-N', 'BEAM'],
                y_label='scRMSD',
                h_line_label='Wild-type',
                title='7JJK')

# %%
plot_line_prot_comp('ll_med', 
                [[pre_stats, bon_10_stats_7jjk_old, beam_10_stats_7jjk_old], \
                    [drakes_stats, bon_10_stats_7jjk_new, beam_10_stats_7jjk_new], \
                    [pre_stats, bon_5_stats_7jjk_old_scrmsd, beam_5_5_stats_7jjk_old_scrmsd], \
                    [drakes_stats, bon_5_stats_7jjk_new_scrmsd, beam_5_5_stats_7jjk_new_scrmsd]], \
                ['Pretrained', 'DRAKES', 'Pretrained-SCRMSD', 'DRAKES-SCRMSD'],\
                ['Baseline', 'Best-of-N', 'BEAM'],
                y_label='ProtGPT Log Likelihood',
                h_line_label='Wild-type',
                title='7JJK')
